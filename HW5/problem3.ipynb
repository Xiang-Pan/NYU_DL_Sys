# %% [markdown]
# # Problem 3 - Kubeflow, MiniKF, Kale 20 points
#
# In this problem we will follow Kubeflow-Kale codelab (link below). You will follow the steps as outlined in the codelab to install Kubeflow with MiniKF, convert a Jupyter Notebook to Kubeflow Pipelines, and run Kubeflow Pipelines from inside a Notebook. For each step below you need to show the commands executed, terminal output, and screenshot of visual output (if any). You also need to give a new name to your GCP project and any resource instance you create, e.g., put your initial in the name string.

# %% [markdown]
# Problem 3 - Kubeflow, MiniKF, Kale
#
# 20 points

# %%
from IPython.display import Markdown, display

display(Markdown("./problem3/3_1.md"))
# Out:
# <!--
#  * @Created by: Xiang Pan
#  * @Date: 2022-04-24 02:32:21
#  * @LastEditors: Xiang Pan
#  * @LastEditTime: 2022-05-06 21:52:10
#  * @Email: xiangpan@nyu.edu
#  * @FilePath: /HW5/problem3/3_1.md
#  * @Description:
# -->
# ## 3-1
#
#
# ### (a)
#
# ![](problem3/figures/2022-04-25-14-12-00.png)
#
#
# ### (b)
#
# ![](problem3/figures/2022-04-24-02-32-26.png)
#
#
# ![](problem3/figures/2022-04-24-02-33-35.png)
#
# ### (c)
#
#
#
# ![](problem3/figures/2022-04-25-14-18-01.png)
#
# ![](problem3/figures/2022-04-25-16-43-16.png)
#
# ![](problem3/figures/2022-04-25-14-22-46.png)
#
# ![](problem3/figures/2022-04-25-14-37-53.png)
#
# ![](problem3/figures/2022-04-25-14-38-16.png)
#
#
# ## 3-2
#
# ### (a)
# Create a notebook server.
#
# ![](problem3/figures/2022-04-25-16-45-19.png)
#
# ![](problem3/figures/2022-04-25-16-46-16.png)
#
# We need to install the pytorch and torchvision package.
#
#
# Or we can choose the pytorch image from the supported list.
#
#
# ### (b)
# Download and run the notebook: We will be using pytorch-classification notbeook from the example repo. Note that the codelab uses a di ff erent example from the repo (titanic dataset ml.ipynb). (3)
#
# ![](problem3/figures/2022-04-26-15-14-18.png)
#
# ![](problem3/figures/2022-04-26-16-13-51.png)
#
#
#
#
# ### (c) Compile
# Convert your notebook to a Kubeflow Pipeline: Enable Kale and then compile and run the pipeline from Kale Deployment Panel. Show output from each of the 5 steps of the pipeline (5)
#
#
# ![](problem3/figures/2022-04-26-16-42-04.png)
#
# ![](problem3/figures/2022-04-26-16-43-33.png)
#
# ![](problem3/figures/2022-04-26-16-44-19.png)
#
# ![](problem3/figures/2022-04-26-16-44-09.png)
#
# ![](problem3/figures/2022-04-26-16-44-00.png)
#
# ### (d)
#
# Show snapshots of ”Graph” and ”Run output” of the experiment. (3)
#
# I'm not sure why I do not have the output of the in the run output section, but I have the output for each of the steps.
#
# ![](problem3/figures/2022-04-26-16-43-48.png)
#
# ![](problem3/figures/2022-04-26-16-43-23.png)
#
#
# ### (e) Cleanup
#
# Cleanup: Destroy the MiniKF VM
#
# ![](problem3/figures/2022-04-26-16-45-24.png)
