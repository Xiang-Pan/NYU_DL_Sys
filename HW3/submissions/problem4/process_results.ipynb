# %% [markdown]
# # Read Results

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./results/resnet44_simple_aug/results.csv")

# %%
data
# Out:
#     epoch  steps  training step  training data  training loss  training prec1  \
# 0       1    195       0.056163       0.005818       1.787805       31.957131
# 1       2    390       0.050171       0.004936       1.294457       52.489984
# 2       3    585       0.050089       0.005094       1.017389       63.501603
# 3       4    780       0.049726       0.004855       0.867839       69.124599
# 4       5    975       0.050032       0.004965       0.773381       72.662260
# ..    ...    ...            ...            ...            ...             ...
# 95     96  18720       0.048046       0.004495       0.016185       99.543269
# 96     97  18915       0.048371       0.004690       0.014763       99.581330
# 97     98  19110       0.047950       0.004401       0.013587       99.623397
# 98     99  19305       0.049305       0.005098       0.013661       99.629407
# 99    100  19500       0.048916       0.004973       0.013038       99.641426
#
# ...
